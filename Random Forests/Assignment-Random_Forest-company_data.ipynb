# %% [markdown]
# ## Assignment_Random_Forest_Company_dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline#for encoding

from sklearn.preprocessing import LabelEncoder#for train test splitting
from sklearn.model_selection import train_test_split#for decision tree object
from sklearn.tree import DecisionTreeClassifier#for checking testing results
from sklearn.metrics import classification_report, confusion_matrix#for visualizing tree 
from sklearn.tree import plot_tree

import warnings
warnings.filterwarnings('ignore')
# Out:
# UsageError: unrecognized arguments: encoding

# %%
# Read in data and display first 5 rows
features = pd.read_csv('Company_Data.csv')
features.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
#getting information of dataset
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
features.shape
# Out:
# (400, 11)

# %%
features.isnull().any()
# Out:
# Sales          False
# CompPrice      False
# Income         False
# Advertising    False
# Population     False
# Price          False
# ShelveLoc      False
# Age            False
# Education      False
# Urban          False
# US             False
# dtype: bool

# %%
features[features.duplicated()].shape
# Out:
# (0, 11)

# %%
features.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
#Creating dummy vairables dropping first dummy variable
df=pd.get_dummies(features,columns=['Urban','US'], drop_first=True)

# %%
df['ShelveLoc']=df['ShelveLoc'].map({'Good':1,'Medium':2,'Bad':3})

# %%
df['ShelveLoc'].value_counts()
# Out:
# 2    219
# 3     96
# 1     85
# Name: ShelveLoc, dtype: int64

# %%
def distplot(param):
    plt.figure(figsize=(8,8))
    sns.distplot(df[param], color = "blue", hist_kws={"rwidth":1.0, 'alpha':1.0})
    plt.xticks(np.arange(0,4,1))
    plt.xlabel('\n'+param)
    plt.ylabel('Distribution\n')
    plt.show()
distplot("ShelveLoc")

# %%
# let's plot pair plot to visualise the attributes all at once
sns.pairplot(data=features, hue = 'ShelveLoc')

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120          3   42
# 1  11.22        111      48           16         260     83          1   65
# 2  10.06        113      35           10         269     80          2   59
# 3   7.40        117     100            4         466     97          2   55
# 4   4.15        141      64            3         340    128          3   38
#
#    Education  Urban_Yes  US_Yes
# 0         17          1       1
# 1         10          1       1
# 2         12          1       1
# 3         14          1       1
# 4         13          1       0

# %%
# Having a look at the correlation matrix

fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(features.corr(), annot=True, fmt='.1g', cmap="viridis", cbar=False, linewidths=0.5, linecolor='black')
# Out:
# <ipython-input-15-40bd715be265>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(features.corr(), annot=True, fmt='.1g', cmap="viridis", cbar=False, linewidths=0.5, linecolor='black')

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120          3   42
# 1  11.22        111      48           16         260     83          1   65
# 2  10.06        113      35           10         269     80          2   59
# 3   7.40        117     100            4         466     97          2   55
# 4   4.15        141      64            3         340    128          3   38
#
#    Education  Urban_Yes  US_Yes
# 0         17          1       1
# 1         10          1       1
# 2         12          1       1
# 3         14          1       1
# 4         13          1       0

# %%
x=df.iloc[:,0:6]
y=df['ShelveLoc']

# %%
x
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price
# 0     9.50        138      73           11         276    120
# 1    11.22        111      48           16         260     83
# 2    10.06        113      35           10         269     80
# 3     7.40        117     100            4         466     97
# 4     4.15        141      64            3         340    128
# ..     ...        ...     ...          ...         ...    ...
# 395  12.57        138     108           17         203    128
# 396   6.14        139      23            3          37    120
# 397   7.41        162      26           12         368    159
# 398   5.94        100      79            7         284     95
# 399   9.71        134      37            0          27    120
#
# [400 rows x 6 columns]

# %%
y
# Out:
# 0      3
# 1      1
# 2      2
# 3      2
# 4      3
#       ..
# 395    1
# 396    2
# 397    2
# 398    3
# 399    1
# Name: ShelveLoc, Length: 400, dtype: int64

# %%
df['ShelveLoc'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
colnames = list(df.columns)
colnames
# Out:
# ['Sales',
#  'CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'ShelveLoc',
#  'Age',
#  'Education',
#  'Urban_Yes',
#  'US_Yes']

# %%
# Labels are the values we want to predict
labels = np.array(df['Income'])
# Remove the labels from the features
# axis 1 refers to the columns
features= df.drop('Income', axis = 1)
# Saving feature names for later use
feature_list = list(df.columns)
# Convert to numpy array
features = np.array(df)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state=42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (300, 11)
# Training Labels Shape: (300,)
# Testing Features Shape: (100, 11)
# Testing Labels Shape: (100,)

# %% [markdown]
# ### Establish Baseline

# %%
# The baseline predictions are the historical averages
baseline_preds = test_features[:, feature_list.index('Sales')]
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
# Out:
# Average baseline error:  65.26

# %% [markdown]
# ### Building model

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
model = RandomForestRegressor(n_estimators = 1000, random_state = 42,oob_score=True)

# Train the model on training data
model.fit(train_features, train_labels)
# Out:
# RandomForestRegressor(n_estimators=1000, oob_score=True, random_state=42)

# %%
# checking the oob score
print('checking the oob score',model.oob_score_)
# Out:
# checking the oob score 0.9998453928889988

# %%
print('Train accuracy: {}'.format(model.score(train_features, train_labels)))
# Out:
# Train accuracy: 0.9999790088485646

# %%
print('Test accuracy: {}'.format(model.score(test_features, test_labels)))
# Out:
# Test accuracy: 0.9997645164626264

# %%
# Use the forest's predict method on the test data
predictions = model.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.27 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 99.58 %.

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(100,50))
plot_tree(model.estimators_[190], feature_names = model.predict(train_features),class_names=df.ShelveLoc.unique(),filled=True)
plt.show()
